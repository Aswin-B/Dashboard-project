# %%
import pandas as pd

# %%
df = pd.read_csv('../notebooks/optimized_data.csv')
df
# Out:
#         encounter_id  patient_nbr             race  gender      age  \
# 0            2278392      8222157        Caucasian  Female   [0-10)
# 1             149190     55629189        Caucasian  Female  [10-20)
# 2              64410     86047875  AfricanAmerican  Female  [20-30)
# 3             500364     82442376        Caucasian    Male  [30-40)
# 4              16680     42519267        Caucasian    Male  [40-50)
# ...              ...          ...              ...     ...      ...
# 101758     443847548    100162476  AfricanAmerican    Male  [70-80)
# 101759     443847782     74694222  AfricanAmerican  Female  [80-90)
# 101760     443854148     41088789        Caucasian    Male  [70-80)
# 101761     443857166     31693671        Caucasian  Female  [80-90)
# 101762     443867222    175429310        Caucasian    Male  [70-80)
#
#        admission_type_id       discharge_disposition_id  \
# 0                    NaN                     Not Mapped
# ...

# %% [markdown]
# # Changing the max_glu_serum values

# %%
df['max_glu_serum'].value_counts()
# Out:
# None    96417
# Norm     2597
# >200     1485
# >300     1264
# Name: max_glu_serum, dtype: int64

# %%
max_glu_serum_new = df['max_glu_serum'].map({
    
    'None': 'None',
    'Norm': 'Normal',
    '>200': 'Prediabetes',
    '>300': 'Diabetes'
    
})

# %%
max_glu_serum_new.value_counts()
# Out:
# None           96417
# Normal          2597
# Prediabetes     1485
# Diabetes        1264
# Name: max_glu_serum, dtype: int64

# %%
df.columns
# Out:
# Index(['encounter_id', 'patient_nbr', 'race', 'gender', 'age',
#        'admission_type_id', 'discharge_disposition_id',
#        'discharge_disposition_id_new', 'admission_source_id',
#        'admission_source_id_new', 'time_in_hospital', 'medical_specialty',
#        'num_lab_procedures', 'num_procedures', 'num_medications',
#        'number_outpatient', 'number_emergency', 'number_inpatient', 'diag_1',
#        'diag_2', 'diag_3', 'number_diagnoses', 'max_glu_serum', 'A1Cresult',
#        'metformin', 'repaglinide', 'nateglinide', 'chlorpropamide',
#        'glimepiride', 'acetohexamide', 'glipizide', 'glyburide', 'tolbutamide',
#        'pioglitazone', 'rosiglitazone', 'acarbose', 'miglitol', 'troglitazone',
#        'tolazamide', 'examide', 'citoglipton', 'insulin',
#        'glyburide-metformin', 'glipizide-metformin',
#        'glimepiride-pioglitazone', 'metformin-rosiglitazone',
#        'metformin-pioglitazone', 'change', 'diabetesMed', 'readmitted'],
# ...

# %%
df.insert(23, 'max_glu_serum_new', max_glu_serum_new)

# %%
df['max_glu_serum_new'].value_counts()
# Out:
# None           96417
# Normal          2597
# Prediabetes     1485
# Diabetes        1264
# Name: max_glu_serum_new, dtype: int64

# %%
df.columns
# Out:
# Index(['encounter_id', 'patient_nbr', 'race', 'gender', 'age',
#        'admission_type_id', 'discharge_disposition_id',
#        'discharge_disposition_id_new', 'admission_source_id',
#        'admission_source_id_new', 'time_in_hospital', 'medical_specialty',
#        'num_lab_procedures', 'num_procedures', 'num_medications',
#        'number_outpatient', 'number_emergency', 'number_inpatient', 'diag_1',
#        'diag_2', 'diag_3', 'number_diagnoses', 'max_glu_serum',
#        'max_glu_serum_new', 'A1Cresult', 'metformin', 'repaglinide',
#        'nateglinide', 'chlorpropamide', 'glimepiride', 'acetohexamide',
#        'glipizide', 'glyburide', 'tolbutamide', 'pioglitazone',
#        'rosiglitazone', 'acarbose', 'miglitol', 'troglitazone', 'tolazamide',
#        'examide', 'citoglipton', 'insulin', 'glyburide-metformin',
#        'glipizide-metformin', 'glimepiride-pioglitazone',
#        'metformin-rosiglitazone', 'metformin-pioglitazone', 'change',
# ...

# %% [markdown]
# # Changing the a1c result values

# %%
df['A1Cresult'].value_counts()
# Out:
# None    84745
# >8       8216
# Norm     4990
# >7       3812
# Name: A1Cresult, dtype: int64

# %%
A1Cresult = df['A1Cresult'].map({
    
    'None': 'None',
    '>8': 'Diabetes',
    'Norm': 'Normal',
    '>7': 'Prediabetes'
    
})

# %%
A1Cresult.value_counts()
# Out:
# None           84745
# Diabetes        8216
# Normal          4990
# Prediabetes     3812
# Name: A1Cresult, dtype: int64

# %%
df.insert(25, 'A1Cresult_new', A1Cresult)

# %%
df['A1Cresult_new'].value_counts()
# Out:
# None           84745
# Diabetes        8216
# Normal          4990
# Prediabetes     3812
# Name: A1Cresult_new, dtype: int64

# %%
df.columns
# Out:
# Index(['encounter_id', 'patient_nbr', 'race', 'gender', 'age',
#        'admission_type_id', 'discharge_disposition_id',
#        'discharge_disposition_id_new', 'admission_source_id',
#        'admission_source_id_new', 'time_in_hospital', 'medical_specialty',
#        'num_lab_procedures', 'num_procedures', 'num_medications',
#        'number_outpatient', 'number_emergency', 'number_inpatient', 'diag_1',
#        'diag_2', 'diag_3', 'number_diagnoses', 'max_glu_serum',
#        'max_glu_serum_new', 'A1Cresult', 'A1Cresult_new', 'metformin',
#        'repaglinide', 'nateglinide', 'chlorpropamide', 'glimepiride',
#        'acetohexamide', 'glipizide', 'glyburide', 'tolbutamide',
#        'pioglitazone', 'rosiglitazone', 'acarbose', 'miglitol', 'troglitazone',
#        'tolazamide', 'examide', 'citoglipton', 'insulin',
#        'glyburide-metformin', 'glipizide-metformin',
#        'glimepiride-pioglitazone', 'metformin-rosiglitazone',
# ...

# %%
df['readmitted'].value_counts()
# Out:
# NO     54861
# >30    35545
# <30    11357
# Name: readmitted, dtype: int64

# %%
readmitted_new = df['readmitted'].map({
    
    'NO': 'NO',
    '>30': '>30 days',
    '<30': '<30 days'
    
})

# %%
readmitted_new.value_counts()
# Out:
# NO          54861
# >30 days    35545
# <30 days    11357
# Name: readmitted, dtype: int64

# %%
df.columns
# Out:
# Index(['encounter_id', 'patient_nbr', 'race', 'gender', 'age',
#        'admission_type_id', 'discharge_disposition_id',
#        'discharge_disposition_id_new', 'admission_source_id',
#        'admission_source_id_new', 'time_in_hospital', 'medical_specialty',
#        'num_lab_procedures', 'num_procedures', 'num_medications',
#        'number_outpatient', 'number_emergency', 'number_inpatient', 'diag_1',
#        'diag_2', 'diag_3', 'number_diagnoses', 'max_glu_serum',
#        'max_glu_serum_new', 'A1Cresult', 'A1Cresult_new', 'metformin',
#        'repaglinide', 'nateglinide', 'chlorpropamide', 'glimepiride',
#        'acetohexamide', 'glipizide', 'glyburide', 'tolbutamide',
#        'pioglitazone', 'rosiglitazone', 'acarbose', 'miglitol', 'troglitazone',
#        'tolazamide', 'examide', 'citoglipton', 'insulin',
#        'glyburide-metformin', 'glipizide-metformin',
#        'glimepiride-pioglitazone', 'metformin-rosiglitazone',
# ...

# %%
df.insert(52, 'readmitted_new', readmitted_new)

# %%
df.columns
# Out:
# Index(['encounter_id', 'patient_nbr', 'race', 'gender', 'age',
#        'admission_type_id', 'discharge_disposition_id',
#        'discharge_disposition_id_new', 'admission_source_id',
#        'admission_source_id_new', 'time_in_hospital', 'medical_specialty',
#        'num_lab_procedures', 'num_procedures', 'num_medications',
#        'number_outpatient', 'number_emergency', 'number_inpatient', 'diag_1',
#        'diag_2', 'diag_3', 'number_diagnoses', 'max_glu_serum',
#        'max_glu_serum_new', 'A1Cresult', 'A1Cresult_new', 'metformin',
#        'repaglinide', 'nateglinide', 'chlorpropamide', 'glimepiride',
#        'acetohexamide', 'glipizide', 'glyburide', 'tolbutamide',
#        'pioglitazone', 'rosiglitazone', 'acarbose', 'miglitol', 'troglitazone',
#        'tolazamide', 'examide', 'citoglipton', 'insulin',
#        'glyburide-metformin', 'glipizide-metformin',
#        'glimepiride-pioglitazone', 'metformin-rosiglitazone',
# ...

# %%
df['readmitted_new'].value_counts()
# Out:
# NO          54861
# >30 days    35545
# <30 days    11357
# Name: readmitted_new, dtype: int64

# %%
# df.to_csv("processed_data.csv", index=False)

# %%
df
# Out:
#         encounter_id  patient_nbr             race  gender      age  \
# 0            2278392      8222157        Caucasian  Female   [0-10)
# 1             149190     55629189        Caucasian  Female  [10-20)
# 2              64410     86047875  AfricanAmerican  Female  [20-30)
# 3             500364     82442376        Caucasian    Male  [30-40)
# 4              16680     42519267        Caucasian    Male  [40-50)
# ...              ...          ...              ...     ...      ...
# 101758     443847548    100162476  AfricanAmerican    Male  [70-80)
# 101759     443847782     74694222  AfricanAmerican  Female  [80-90)
# 101760     443854148     41088789        Caucasian    Male  [70-80)
# 101761     443857166     31693671        Caucasian  Female  [80-90)
# 101762     443867222    175429310        Caucasian    Male  [70-80)
#
#        admission_type_id       discharge_disposition_id  \
# 0                    NaN                     Not Mapped
# ...

# %%
time = df[(df['gender'] == 'Female') & (df['age'] == '[0-10)')]
time
# Out:
#         encounter_id  patient_nbr       race  gender     age  \
# 0            2278392      8222157  Caucasian  Female  [0-10)
# 216          2735964      2359485  Caucasian  Female  [0-10)
# 270          2968386      8568180  Caucasian  Female  [0-10)
# 294          3108096      5832918  Caucasian  Female  [0-10)
# 474          4140282      7443135  Caucasian  Female  [0-10)
# ...              ...          ...        ...     ...     ...
# 72476      211990014     89312436  Caucasian  Female  [0-10)
# 80352      247730952     20103048   Hispanic  Female  [0-10)
# 84929      268539312     74164347  Caucasian  Female  [0-10)
# 98897      406743404    110172294  Caucasian  Female  [0-10)
# 100784     430828958    146717159  Caucasian  Female  [0-10)
#
#        admission_type_id                           discharge_disposition_id  \
# 0                    NaN                                         Not Mapped
# 216                  NaN                                         Not Mapped
# ...

# %%
print(f"{time['time_in_hospital'].unique().min()} to {time['time_in_hospital'].unique().max()}")
# Out:
# 1 to 7

# %%
time['time_in_hospital'].unique()
# Out:
# array([1, 3, 2, 5, 4, 6, 7], dtype=int64)
