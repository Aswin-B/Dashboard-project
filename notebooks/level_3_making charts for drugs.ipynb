# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Data

# %%
df = pd.read_csv('../notebooks/final_data.csv')
df.head()
# Out:
#    encounter_id  patient_nbr             race  gender      age  \
# 0       2278392      8222157        Caucasian  Female   [0-10)
# 1        149190     55629189        Caucasian  Female  [10-20)
# 2         64410     86047875  AfricanAmerican  Female  [20-30)
# 3        500364     82442376        Caucasian    Male  [30-40)
# 4         16680     42519267        Caucasian    Male  [40-50)
#
#   admission_type_id discharge_disposition_id admission_source_id  \
# 0               NaN               Not Mapped  Physician Referral
# 1         Emergency       Discharged to home      Emergency Room
# 2         Emergency       Discharged to home      Emergency Room
# 3         Emergency       Discharged to home      Emergency Room
# 4         Emergency       Discharged to home      Emergency Room
#
#    time_in_hospital         medical_specialty  ...  citoglipton  insulin  \
# 0                 1  Pediatrics-Endocrinology  ...           No       No
# ...

# %% [markdown]
# # The total number of visited patients given the drug molecule along with the categories (up, down, steady, no).

# %% [markdown]
# # 1. Metformin

# %%
df['metformin'].value_counts()
# Out:
# No        81776
# Steady    18345
# Up         1067
# Down        575
# Name: metformin, dtype: int64

# %%
metformin = df.loc[df['metformin'] != 'No']['metformin'].value_counts()
metformin
# Out:
# Steady    18345
# Up         1067
# Down        575
# Name: metformin, dtype: int64

# %%
fig = plt.figure()
ax = fig.add_subplot()

# plotting line

ax.pie(metformin, labels=metformin.index, autopct='%1.1f%%')

# setting title
ax.set_title('The composition of Dosage levels prescribed to the patients')

plt.show()

# %% [markdown]
# # 2. Repaglinide

# %%
df['repaglinide'].value_counts()
# Out:
# No        100224
# Steady      1384
# Up           110
# Down          45
# Name: repaglinide, dtype: int64

# %%
repaglinide = df.loc[df['repaglinide'] != 'No']['repaglinide'].value_counts()
repaglinide
# Out:
# Steady    1384
# Up         110
# Down        45
# Name: repaglinide, dtype: int64

# %%
fig = plt.figure()
ax = fig.add_subplot()

# plotting line

ax.pie(repaglinide, labels=repaglinide.index, autopct='%1.1f%%')

# setting title
ax.set_title('The composition of Dosage levels prescribed to the patients')

plt.show()

# %% [markdown]
# # 3. Nateglinide

# %%
df['nateglinide'].value_counts()
# Out:
# No        101060
# Steady       668
# Up            24
# Down          11
# Name: nateglinide, dtype: int64

# %%
nateglinide = df.loc[df['nateglinide'] != 'No']['nateglinide'].value_counts()
nateglinide
# Out:
# Steady    668
# Up         24
# Down       11
# Name: nateglinide, dtype: int64

# %%
fig = plt.figure()
ax = fig.add_subplot()

# plotting line

ax.pie(nateglinide, labels=nateglinide.index, autopct='%1.1f%%')

# setting title
ax.set_title('The composition of Dosage levels prescribed to the patients')

plt.show()

# %% [markdown]
# # 4. Chlorpropamide

# %%
df['chlorpropamide'].value_counts()
# Out:
# No        101677
# Steady        79
# Up             6
# Down           1
# Name: chlorpropamide, dtype: int64

# %%
chlorpropamide = df.loc[df['chlorpropamide'] != 'No']['chlorpropamide'].value_counts()
chlorpropamide
# Out:
# Steady    79
# Up         6
# Down       1
# Name: chlorpropamide, dtype: int64

# %%
fig = plt.figure()
ax = fig.add_subplot()

# plotting line

ax.pie(chlorpropamide, labels=chlorpropamide.index, autopct='%1.1f%%')

# setting title
ax.set_title('The composition of Dosage levels prescribed to the patients')

plt.show()

# %% [markdown]
# # 5. Glimepiride

# %%
df['glimepiride'].value_counts()
# Out:
# No        96572
# Steady     4670
# Up          327
# Down        194
# Name: glimepiride, dtype: int64

# %%
glimepiride = df.loc[df['glimepiride'] != 'No']['glimepiride'].value_counts()
glimepiride
# Out:
# Steady    4670
# Up         327
# Down       194
# Name: glimepiride, dtype: int64

# %%
fig = plt.figure()
ax = fig.add_subplot()

# plotting line

ax.pie(glimepiride, labels=glimepiride.index, autopct='%1.1f%%')

# setting title
ax.set_title('The composition of Dosage levels prescribed to the patients')

plt.show()

# %% [markdown]
# # 6. Acetohexamide

# %%
df['acetohexamide'].value_counts()
# Out:
# No        101762
# Steady         1
# Name: acetohexamide, dtype: int64

# %%
acetohexamide = df.loc[df['acetohexamide'] != 'No']['acetohexamide'].value_counts()
acetohexamide
# Out:
# Steady    1
# Name: acetohexamide, dtype: int64

# %%
fig = plt.figure()
ax = fig.add_subplot()

# plotting line

ax.pie(acetohexamide, labels=acetohexamide.index, autopct='%1.1f%%')

# setting title
ax.set_title('The composition of Dosage levels prescribed to the patients')

plt.show()

# %% [markdown]
# # 7. Glipizide

# %%
df['glipizide'].value_counts()
# Out:
# No        89078
# Steady    11355
# Up          770
# Down        560
# Name: glipizide, dtype: int64

# %%
glipizide = df.loc[df['glipizide'] != 'No']['glipizide'].value_counts()
glipizide
# Out:
# Steady    11355
# Up          770
# Down        560
# Name: glipizide, dtype: int64

# %%
fig = plt.figure()
ax = fig.add_subplot()

# plotting line

ax.pie(glipizide, labels=glipizide.index, autopct='%1.1f%%')

# setting title
ax.set_title('The composition of Dosage levels prescribed to the patients')

plt.show()

# %% [markdown]
# # 8. Glyburide

# %%
df['glyburide'].value_counts()
# Out:
# No        91113
# Steady     9274
# Up          812
# Down        564
# Name: glyburide, dtype: int64

# %%
glyburide = df.loc[df['glyburide'] != 'No']['glyburide'].value_counts()
glyburide
# Out:
# Steady    9274
# Up         812
# Down       564
# Name: glyburide, dtype: int64

# %%
fig = plt.figure()
ax = fig.add_subplot()

# plotting line

ax.pie(glyburide, labels=glyburide.index, autopct='%1.1f%%')

# setting title
ax.set_title('The composition of Dosage levels prescribed to the patients')

plt.show()

# %% [markdown]
# # 9. Tolbutamide

# %%
df['tolbutamide'].value_counts()
# Out:
# No        101740
# Steady        23
# Name: tolbutamide, dtype: int64

# %%
tolbutamide = df.loc[df['tolbutamide'] != 'No']['tolbutamide'].value_counts()
tolbutamide
# Out:
# Steady    23
# Name: tolbutamide, dtype: int64

# %%
fig = plt.figure()
ax = fig.add_subplot()

# plotting line

ax.pie(tolbutamide, labels=tolbutamide.index, autopct='%1.1f%%')

# setting title
ax.set_title('The composition of Dosage levels prescribed to the patients')

plt.show()

# %% [markdown]
# # 10. Pioglitazone

# %%
df['pioglitazone'].value_counts()
# Out:
# No        94436
# Steady     6975
# Up          234
# Down        118
# Name: pioglitazone, dtype: int64

# %%
pioglitazone = df.loc[df['pioglitazone'] != 'No']['pioglitazone'].value_counts()
pioglitazone
# Out:
# Steady    6975
# Up         234
# Down       118
# Name: pioglitazone, dtype: int64

# %%
fig = plt.figure()
ax = fig.add_subplot()

# plotting line

ax.pie(pioglitazone, labels=pioglitazone.index, autopct='%1.1f%%')

# setting title
ax.set_title('The composition of Dosage levels prescribed to the patients')

plt.show()

# %% [markdown]
# # 11. Rosiglitazone

# %%
df['rosiglitazone'].value_counts()
# Out:
# No        95399
# Steady     6099
# Up          178
# Down         87
# Name: rosiglitazone, dtype: int64

# %%
rosiglitazone = df.loc[df['rosiglitazone'] != 'No']['rosiglitazone'].value_counts()
rosiglitazone
# Out:
# Steady    6099
# Up         178
# Down        87
# Name: rosiglitazone, dtype: int64

# %%
fig = plt.figure()
ax = fig.add_subplot()

# plotting line

ax.pie(rosiglitazone, labels=rosiglitazone.index, autopct='%1.1f%%')

# setting title
ax.set_title('The composition of Dosage levels prescribed to the patients')

plt.show()

# %% [markdown]
# # 12. Acarbose

# %%
df['acarbose'].value_counts()
# Out:
# No        101455
# Steady       295
# Up            10
# Down           3
# Name: acarbose, dtype: int64

# %%
acarbose = df.loc[df['acarbose'] != 'No']['acarbose'].value_counts()
acarbose
# Out:
# Steady    295
# Up         10
# Down        3
# Name: acarbose, dtype: int64

# %%
fig = plt.figure()
ax = fig.add_subplot()

# plotting line

ax.pie(acarbose, labels=acarbose.index, autopct='%1.1f%%')

# setting title
ax.set_title('The composition of Dosage levels prescribed to the patients')

plt.show()

# %% [markdown]
# # 13. Miglitol

# %%
df['miglitol'].value_counts()
# Out:
# No        101725
# Steady        31
# Down           5
# Up             2
# Name: miglitol, dtype: int64

# %%
miglitol = df.loc[df['miglitol'] != 'No']['miglitol'].value_counts()
miglitol
# Out:
# Steady    31
# Down       5
# Up         2
# Name: miglitol, dtype: int64

# %%
fig = plt.figure()
ax = fig.add_subplot()

# plotting line

ax.pie(miglitol, labels=miglitol.index, autopct='%1.1f%%')

# setting title
ax.set_title('The composition of Dosage levels prescribed to the patients')

plt.show()

# %% [markdown]
# # 14. Troglitazone

# %%
df['troglitazone'].value_counts()
# Out:
# No        101760
# Steady         3
# Name: troglitazone, dtype: int64

# %%
troglitazone = df.loc[df['troglitazone'] != 'No']['troglitazone'].value_counts()
troglitazone
# Out:
# Steady    3
# Name: troglitazone, dtype: int64

# %%
fig = plt.figure()
ax = fig.add_subplot()

# plotting line

ax.pie(troglitazone, labels=troglitazone.index, autopct='%1.1f%%')

# setting title
ax.set_title('The composition of Dosage levels prescribed to the patients')

plt.show()

# %% [markdown]
# # 15. Tolazamide

# %%
df['tolazamide'].value_counts()
# Out:
# No        101724
# Steady        38
# Up             1
# Name: tolazamide, dtype: int64

# %%
tolazamide = df.loc[df['tolazamide'] != 'No']['tolazamide'].value_counts()
tolazamide
# Out:
# Steady    38
# Up         1
# Name: tolazamide, dtype: int64

# %%
fig = plt.figure()
ax = fig.add_subplot()

# plotting line

ax.pie(tolazamide, labels=tolazamide.index, autopct='%1.1f%%')

# setting title
ax.set_title('The composition of Dosage levels prescribed to the patients')

plt.show()

# %% [markdown]
# # Examide and Citoglipton column removed

# %%
df['examide'].value_counts()
# Out:
# No    101763
# Name: examide, dtype: int64

# %%
df['citoglipton'].value_counts()
# Out:
# No    101763
# Name: citoglipton, dtype: int64

# %% [markdown]
# # 16. Insulin

# %%
df['insulin'].value_counts()
# Out:
# No        47380
# Steady    30849
# Down      12218
# Up        11316
# Name: insulin, dtype: int64

# %%
insulin = df.loc[df['insulin'] != 'No']['insulin'].value_counts()
insulin
# Out:
# Steady    30849
# Down      12218
# Up        11316
# Name: insulin, dtype: int64

# %%
fig = plt.figure()
ax = fig.add_subplot()

# plotting line

ax.pie(insulin, labels=insulin.index, autopct='%1.1f%%')

# setting title
ax.set_title('The composition of Dosage levels prescribed to the patients')

plt.show()

# %% [markdown]
# # 17. Glyburide-metformin

# %%
df['glyburide-metformin'].value_counts()
# Out:
# No        101057
# Steady       692
# Up             8
# Down           6
# Name: glyburide-metformin, dtype: int64

# %%
glyburide_metformin = df.loc[df['glyburide-metformin'] != 'No']['glyburide-metformin'].value_counts()
glyburide_metformin
# Out:
# Steady    692
# Up          8
# Down        6
# Name: glyburide-metformin, dtype: int64

# %%
fig = plt.figure()
ax = fig.add_subplot()

# plotting line

ax.pie(glyburide_metformin, labels=glyburide_metformin.index, autopct='%1.1f%%')

# setting title
ax.set_title('The composition of Dosage levels prescribed to the patients')

plt.show()

# %% [markdown]
# # 18. Glipizide-metformin

# %%
df['glipizide-metformin'].value_counts()
# Out:
# No        101750
# Steady        13
# Name: glipizide-metformin, dtype: int64

# %%
glipizide_metformin = df.loc[df['glipizide-metformin'] != 'No']['glipizide-metformin'].value_counts()
glipizide_metformin
# Out:
# Steady    13
# Name: glipizide-metformin, dtype: int64

# %%
fig = plt.figure()
ax = fig.add_subplot()

# plotting line

ax.pie(glipizide_metformin, labels=glipizide_metformin.index, autopct='%1.1f%%')

# setting title
ax.set_title('The composition of Dosage levels prescribed to the patients')

plt.show()

# %% [markdown]
# # 19. Glimepiride-pioglitazone

# %%
df['glimepiride-pioglitazone'].value_counts()
# Out:
# No        101762
# Steady         1
# Name: glimepiride-pioglitazone, dtype: int64

# %%
glimepiride_pioglitazone = df.loc[df['glimepiride-pioglitazone'] != 'No']['glimepiride-pioglitazone'].value_counts()
glimepiride_pioglitazone
# Out:
# Steady    1
# Name: glimepiride-pioglitazone, dtype: int64

# %%
fig = plt.figure()
ax = fig.add_subplot()

# plotting line

ax.pie(glimepiride_pioglitazone, labels=glimepiride_pioglitazone.index, autopct='%1.1f%%')

# setting title
ax.set_title('The composition of Dosage levels prescribed to the patients')

plt.show()

# %% [markdown]
# # 20. Metformin-rosiglitazone

# %%
df['metformin-rosiglitazone'].value_counts()
# Out:
# No        101761
# Steady         2
# Name: metformin-rosiglitazone, dtype: int64

# %%
metformin_rosiglitazone = df.loc[df['metformin-rosiglitazone'] != 'No']['metformin-rosiglitazone'].value_counts()
metformin_rosiglitazone
# Out:
# Steady    2
# Name: metformin-rosiglitazone, dtype: int64

# %%
fig = plt.figure()
ax = fig.add_subplot()

# plotting line

ax.pie(metformin_rosiglitazone, labels=metformin_rosiglitazone.index, autopct='%1.1f%%')

# setting title
ax.set_title('The composition of Dosage levels prescribed to the patients')

plt.show()

# %% [markdown]
# # 21. Metformin-pioglitazone

# %%
df['metformin-pioglitazone'].value_counts()
# Out:
# No        101762
# Steady         1
# Name: metformin-pioglitazone, dtype: int64

# %%
metformin_pioglitazone = df.loc[df['metformin-pioglitazone'] != 'No']['metformin-pioglitazone'].value_counts()
metformin_pioglitazone
# Out:
# Steady    1
# Name: metformin-pioglitazone, dtype: int64

# %%
fig = plt.figure()
ax = fig.add_subplot()

# plotting line

ax.pie(metformin_pioglitazone, labels=metformin_pioglitazone.index, autopct='%1.1f%%')

# setting title
ax.set_title('The composition of Dosage levels prescribed to the patients')

plt.show()
