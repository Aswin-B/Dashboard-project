# %%
import pandas as pd

# %%
df = pd.read_csv('../notebooks/final_data.csv')
df
# Out:
#         encounter_id  patient_nbr             race  gender      age  \
# 0            2278392      8222157        Caucasian  Female   [0-10)
# 1             149190     55629189        Caucasian  Female  [10-20)
# 2              64410     86047875  AfricanAmerican  Female  [20-30)
# 3             500364     82442376        Caucasian    Male  [30-40)
# 4              16680     42519267        Caucasian    Male  [40-50)
# ...              ...          ...              ...     ...      ...
# 101758     443847548    100162476  AfricanAmerican    Male  [70-80)
# 101759     443847782     74694222  AfricanAmerican  Female  [80-90)
# 101760     443854148     41088789        Caucasian    Male  [70-80)
# 101761     443857166     31693671        Caucasian  Female  [80-90)
# 101762     443867222    175429310        Caucasian    Male  [70-80)
#
#        admission_type_id       discharge_disposition_id  \
# 0                    NaN                     Not Mapped
# ...

# %% [markdown]
# # Adding new discharge disposition id column w.r.t its values

# %%
discharge_disposition_id_new = df['discharge_disposition_id'].map({
    
    'Discharged to home': 'D1',
    'Discharged/transferred to another short term hospital': 'D2',
    'Discharged/transferred to SNF': 'D3',
    'Discharged/transferred to ICF': 'D4',
    'Discharged/transferred to another type of inpatient care institution': 'D5',
    'Discharged/transferred to home with home health service': 'D6',
    'Left AMA': 'D7',
    'Discharged/transferred to home under care of Home IV provider': 'D8',
    'Admitted as an inpatient to this hospital': 'D9',
    'Neonate discharged to another hospital for neonatal aftercare': 'D10',
    'Expired': 'D11',
    'Still patient or expected to return for outpatient services': 'D12',
    'Hospice / home': 'D13',
    'Hospice / medical facility': 'D14',
    'Discharged/transferred within this institution to Medicare approved swing bed': 'D15',
    'Discharged/transferred/referred another institution for outpatient services': 'D16',
    'Discharged/transferred/referred to this institution for outpatient services': 'D17',
    'NULL': 'D18',
    'Expired at home. Medicaid only, hospice.': 'D19',
    'Expired in a medical facility. Medicaid only, hospice.': 'D20',
    'Expired, place unknown. Medicaid only, hospice.': 'D21',
    'Discharged/transferred to another rehab fac including rehab units of a hospital .': 'D22',
    'Discharged/transferred to a long term care hospital.': 'D23',
    'Discharged/transferred to a nursing facility certified under Medicaid but not certified under Medicare.': 'D24',
    'Not Mapped': 'D25',
    'Unknown/Invalid': 'D26',
    'Discharged/transferred to another Type of Health Care Institution not Defined Elsewhere': 'D30',
    'Discharged/transferred to a federal health care facility.': 'D27',
    'Discharged/transferred/referred to a psychiatric hospital of psychiatric distinct part unit of a hospital': 'D28',
    'Discharged/transferred to a Critical Access Hospital (CAH).': 'D29'
    
})

# %%
discharge_disposition_id_new
# Out:
# 0         D25
# 1          D1
# 2          D1
# 3          D1
# 4          D1
#          ...
# 101758     D3
# 101759     D4
# 101760     D1
# 101761     D3
# 101762     D1
# Name: discharge_disposition_id, Length: 101763, dtype: object

# %%
df.insert(7, 'discharge_disposition_id_new', discharge_disposition_id_new)

# %%
df
# Out:
#         encounter_id  patient_nbr             race  gender      age  \
# 0            2278392      8222157        Caucasian  Female   [0-10)
# 1             149190     55629189        Caucasian  Female  [10-20)
# 2              64410     86047875  AfricanAmerican  Female  [20-30)
# 3             500364     82442376        Caucasian    Male  [30-40)
# 4              16680     42519267        Caucasian    Male  [40-50)
# ...              ...          ...              ...     ...      ...
# 101758     443847548    100162476  AfricanAmerican    Male  [70-80)
# 101759     443847782     74694222  AfricanAmerican  Female  [80-90)
# 101760     443854148     41088789        Caucasian    Male  [70-80)
# 101761     443857166     31693671        Caucasian  Female  [80-90)
# 101762     443867222    175429310        Caucasian    Male  [70-80)
#
#        admission_type_id       discharge_disposition_id  \
# 0                    NaN                     Not Mapped
# ...

# %% [markdown]
# # Adding the admission source id_new column w.r.t its values

# %%
admission_source_id_new = df['admission_source_id'].map({
    
    'Physician Referral': 'AS1',
    'Clinic Referral': 'AS2',
    'HMO Referral': 'AS3',
    'Transfer from a hospital': 'AS4',
    'Transfer from a Skilled Nursing Facility (SNF)': 'AS5',
    'Transfer from another health care facility': 'AS6',
    'Emergency Room': 'AS7',
    'Court/Law Enforcement': 'AS8',
    'Not Available': 'AS9',
    'Transfer from critial access hospital': 'AS10',
    'Normal Delivery': 'AS11',
    'Premature Delivery': 'AS12',
    'Sick Baby': 'AS13',
    'Extramural Birth': 'AS14',
    'Not Available': 'AS15',
    'NULL': 'AS17',
    'Transfer From Another Home Health Agency': 'AS18',
    'Readmission to Same Home Health Agency': 'AS19',
    'Not Mapped': 'AS20',
    'Unknown/Invalid': 'AS21',
    'Transfer from hospital inpt/same fac reslt in a sep claim': 'AS22',
    'Born inside this hospital': 'AS23',
    'Born outside this hospital': 'AS24',
    'Transfer from Ambulatory Surgery Center': 'AS25',
    'Transfer from Hospice': 'AS26'
})

# %%
df.insert(9, 'admission_source_id_new', admission_source_id_new)

# %%
df
# Out:
#         encounter_id  patient_nbr             race  gender      age  \
# 0            2278392      8222157        Caucasian  Female   [0-10)
# 1             149190     55629189        Caucasian  Female  [10-20)
# 2              64410     86047875  AfricanAmerican  Female  [20-30)
# 3             500364     82442376        Caucasian    Male  [30-40)
# 4              16680     42519267        Caucasian    Male  [40-50)
# ...              ...          ...              ...     ...      ...
# 101758     443847548    100162476  AfricanAmerican    Male  [70-80)
# 101759     443847782     74694222  AfricanAmerican  Female  [80-90)
# 101760     443854148     41088789        Caucasian    Male  [70-80)
# 101761     443857166     31693671        Caucasian  Female  [80-90)
# 101762     443867222    175429310        Caucasian    Male  [70-80)
#
#        admission_type_id       discharge_disposition_id  \
# 0                    NaN                     Not Mapped
# ...

# %%
df.to_csv("optimized_data.csv", index=False)
